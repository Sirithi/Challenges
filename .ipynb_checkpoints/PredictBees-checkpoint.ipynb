# %% [markdown]
# # Predict bee image health

# %% [markdown]
# ## Load the dataset as a dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('bee_data.csv')

print(df.head())
# Out:
#           file     date   time        location  zip code subspecies  \
# 0  041_066.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 1  041_072.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 2  041_073.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 3  041_067.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 4  041_059.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
#
#               health  pollen_carrying   caste
# 0  hive being robbed            False  worker
# 1  hive being robbed            False  worker
# 2  hive being robbed            False  worker
# 3  hive being robbed            False  worker
# 4  hive being robbed            False  worker

# %% [markdown]
# ## Now we create a path column to out dataframe
#
# In this column we will append the directory path to the image from this notebook

# %%
imgPath = "./bee_imgs/bee_imgs/"

# %%
df.reset_index()

for index, row in df.iterrows():
    fileName = row['file']
    df.loc[index,'path'] = imgPath+str(fileName)

# %% [markdown]
# Check if the new column named path has the correct path to the images

# %%
print(df.head())
# Out:
#           file     date   time        location  zip code subspecies  \
# 0  041_066.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 1  041_072.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 2  041_073.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 3  041_067.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 4  041_059.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
#
#               health  pollen_carrying   caste                             path
# 0  hive being robbed            False  worker  ./bee_imgs/bee_imgs/041_066.png
# 1  hive being robbed            False  worker  ./bee_imgs/bee_imgs/041_072.png
# 2  hive being robbed            False  worker  ./bee_imgs/bee_imgs/041_073.png
# 3  hive being robbed            False  worker  ./bee_imgs/bee_imgs/041_067.png
# 4  hive being robbed            False  worker  ./bee_imgs/bee_imgs/041_059.png

# %%
df['health'] = df['health'].replace(['Varroa, Small Hive Beetles', 'few varrao, hive beetles'], 'Varroa, Hive Beetles')

# %% [markdown]
# ## Split the values in train validate and test data

# %%
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\weyns\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### We will split the data in three parts
#
# These parts are going to be train, validate and test. We will use train to make the models, validate to choose the best one and test to see how good it really is.

# %%
codes, uniques = pd.factorize(df['health'])
df['facCat'] = codes

# %%
print(df)
# Out:
#              file     date   time           location  zip code subspecies  \
# 0     041_066.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 1     041_072.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 2     041_073.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 3     041_067.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 4     041_059.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# ...           ...      ...    ...                ...       ...        ...
# 5167  027_011.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5168  027_007.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5169  027_013.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5170  027_012.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5171  027_014.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
#
#                  health  pollen_carrying   caste  \
# 0     hive being robbed            False  worker
# 1     hive being robbed            False  worker
# 2     hive being robbed            False  worker
# 3     hive being robbed            False  worker
# 4     hive being robbed            False  worker
# ...                 ...              ...     ...
# 5167            healthy             True  worker
# 5168            healthy             True  worker
# 5169            healthy            False  worker
# 5170            healthy            False  worker
# 5171            healthy            False  worker
#
#                                  path  facCat
# 0     ./bee_imgs/bee_imgs/041_066.png       0
# 1     ./bee_imgs/bee_imgs/041_072.png       0
# 2     ./bee_imgs/bee_imgs/041_073.png       0
# 3     ./bee_imgs/bee_imgs/041_067.png       0
# 4     ./bee_imgs/bee_imgs/041_059.png       0
# ...                               ...     ...
# 5167  ./bee_imgs/bee_imgs/027_011.png       1
# 5168  ./bee_imgs/bee_imgs/027_007.png       1
# 5169  ./bee_imgs/bee_imgs/027_013.png       1
# 5170  ./bee_imgs/bee_imgs/027_012.png       1
# 5171  ./bee_imgs/bee_imgs/027_014.png       1
#
# [5172 rows x 11 columns]

# %%
df_tv, df_test = train_test_split(df, test_size=0.2, random_state=42, stratify=df['facCat'])

# %%
df_train, df_val = train_test_split(df_tv, test_size=0.2, random_state=42, stratify=df_tv['facCat'])

# %% [markdown]
# **This names list is important for creating the directorys for the images**

# %%
dataFrames = ["df_test", "df_train", "df_val"]

# %%
print(df_train)
# Out:
#              file     date   time              location  zip code  \
# 3151  034_036.png  8/21/18  13:49        Alvin, TX, USA     77511
# 1730  040_426.png  8/21/18  15:56       Athens, GA, USA     30607
# 4777  019_814.png   8/6/18  19:19     Saratoga, CA, USA     95070
# 4637  038_390.png  8/18/18  12:30  Athens, Georgia, USA     30607
# 1943  002_024.png  8/25/18  14:00        Keene, NH, USA      3431
# ...           ...      ...    ...                   ...       ...
# 4207  038_188.png  8/18/18  12:30  Athens, Georgia, USA     30607
# 3961  032_836.png  8/21/18   9:00   Des Moines, IA, USA     50315
# 3448  015_818.png   8/6/18  13:19     Saratoga, CA, USA     95070
# 3858  032_918.png  8/21/18   9:00   Des Moines, IA, USA     50315
# 3699  013_036.png  8/18/18  12:36        Alvin, TX, USA     77511
#
#                  subspecies                health  pollen_carrying   caste  \
# 3151  VSH Italian honey bee         missing queen            False  worker
# 1730      Italian honey bee  Varroa, Hive Beetles            False  worker
# 4777      Italian honey bee               healthy            False  worker
# 4637  1 Mixed local stock 2  Varroa, Hive Beetles            False  worker
# 1943      Russian honey bee               healthy            False  worker
# ...                     ...                   ...              ...     ...
# 4207  1 Mixed local stock 2  Varroa, Hive Beetles            False  worker
# 3961      Russian honey bee               healthy            False  worker
# 3448      Italian honey bee               healthy            False  worker
# 3858      Russian honey bee               healthy            False  worker
# 3699      Italian honey bee          ant problems            False  worker
#
#                                  path  facCat
# 3151  ./bee_imgs/bee_imgs/034_036.png       4
# 1730  ./bee_imgs/bee_imgs/040_426.png       2
# 4777  ./bee_imgs/bee_imgs/019_814.png       1
# 4637  ./bee_imgs/bee_imgs/038_390.png       2
# 1943  ./bee_imgs/bee_imgs/002_024.png       1
# ...                               ...     ...
# 4207  ./bee_imgs/bee_imgs/038_188.png       2
# 3961  ./bee_imgs/bee_imgs/032_836.png       1
# 3448  ./bee_imgs/bee_imgs/015_818.png       1
# 3858  ./bee_imgs/bee_imgs/032_918.png       1
# 3699  ./bee_imgs/bee_imgs/013_036.png       3
#
# [3309 rows x 11 columns]

# %% [markdown]
# ### New dataframes
#
# We now have three dataframes, **df_test**, **df_train**, **df_val**.

# %% [markdown]
# ### Factorize check
#
# Now we also want to know which factorize number equals what state of health. We are going to find that out next.

# %%
uniqueHealths = pd.unique(df['health'])
print(uniqueHealths)
# Out:
# ['hive being robbed' 'healthy' 'Varroa, Hive Beetles' 'ant problems'
#  'missing queen']

# %%
healthStates = {}

df.reset_index()

for index, row in df.iterrows():
    healthOfRow = row['health']
    if healthOfRow not in healthStates:
        healthStates[healthOfRow] = row['facCat']

print(healthStates)
# Out:
# {'hive being robbed': 0, 'healthy': 1, 'Varroa, Hive Beetles': 2, 'ant problems': 3, 'missing queen': 4}

# %% [markdown]
# ### Start making out model

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import os

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### We first need to load all the images from the **df_train**
#
# To do this we need to create a file structure where every dataframe is a file containing folders named after the health state and the images in the corresponding folders.

# %% [markdown]
# This is what we want to print

# %%
for x in dataFrames:
    print(x)
    for y in uniqueHealths:
        print("   " + x + '/' + y)
# Out:
# df_test
#    df_test/hive being robbed
#    df_test/healthy
#    df_test/Varroa, Hive Beetles
#    df_test/ant problems
#    df_test/missing queen
# df_train
#    df_train/hive being robbed
#    df_train/healthy
#    df_train/Varroa, Hive Beetles
#    df_train/ant problems
#    df_train/missing queen
# df_val
#    df_val/hive being robbed
#    df_val/healthy
#    df_val/Varroa, Hive Beetles
#    df_val/ant problems
#    df_val/missing queen

# %%
for x in dataFrames:
    if not os.path.exists(x):
        try:
            os.mkdir(x)
        except FileExistsError:
            print("df directory " + x + " already exists")
    for y in uniqueHealths:
        if not os.path.exists(y):
            try:
                os.mkdir(x + '/' + y)
            except FileExistsError:
                print("health directory " + y + " in " + x + " already exists")
# Out:
# health directory hive being robbed in df_test already exists
# health directory healthy in df_test already exists
# health directory Varroa, Hive Beetles in df_test already exists
# health directory ant problems in df_test already exists
# health directory missing queen in df_test already exists
# health directory hive being robbed in df_train already exists
# health directory healthy in df_train already exists
# health directory Varroa, Hive Beetles in df_train already exists
# health directory ant problems in df_train already exists
# health directory missing queen in df_train already exists
# health directory hive being robbed in df_val already exists
# health directory healthy in df_val already exists
# health directory Varroa, Hive Beetles in df_val already exists
# health directory ant problems in df_val already exists
# health directory missing queen in df_val already exists

# %%
import shutil

# %% [markdown]
# First we delete all the excisting files in the directorys. This is because if we run everything twice the train test split may differentiate.

# %%
for x in dataFrames:
    for y in uniqueHealths:
        folder = (x + '/' + y)
        for filename in os.listdir(folder):
            file_path = os.path.join(folder, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print("big yikes")
                # print('Failed to delete %s. Reason: %s' % (file_path, e))

# %% [markdown]
# For every existing df we create a for loop, in the to path we specify in the first string which dataframe directory we need.

# %% [markdown]
# First we fill the **df_train** directory

# %%
df.reset_index()

for index, row in df_train.iterrows():
    fileName = row['file']
    fromPath = row['path']
    healthPath = row ['health']
    toPath = ("df_train" + '/' + healthPath + '/' + fileName)
    if not os.path.exists(toPath):
        shutil.copy(fromPath, toPath)

# %% [markdown]
# **df_val**

# %%
df.reset_index()

for index, row in df_val.iterrows():
    fileName = row['file']
    fromPath = row['path']
    healthPath = row ['health']
    toPath = ("df_val" + '/' + healthPath + '/' + fileName)
    if not os.path.exists(toPath):
        shutil.copy(fromPath, toPath)

# %% [markdown]
# **df_test**

# %%
df.reset_index()

for index, row in df_test.iterrows():
    fileName = row['file']
    fromPath = row['path']
    healthPath = row ['health']
    toPath = ("df_test" + '/' + healthPath + '/' + fileName)
    if not os.path.exists(toPath):
        shutil.copy(fromPath, toPath)

# %% [markdown]
# ### Download the data into tf

# %%
import pathlib

data_dir = pathlib.Path("./df_train")

image_count = len(list(data_dir.glob('*/*.png')))
print(str(image_count) + " images in this directory")

healthy = list(data_dir.glob('healthy/*'))
print("Look it's a bee!!!")
PIL.Image.open(str(healthy[0]))
# Out:
# 3309 images in this directory
# Look it's a bee!!!
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=68x64 at 0x1FF0C8442B0>

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 3309

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3309 files belonging to 5 classes.
# Using 661 files for validation.
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>

# %%
data_dir_val = pathlib.Path("./df_val")

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_val,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 828 files belonging to 5 classes.
# Using 165 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Varroa, Hive Beetles', 'ant problems', 'healthy', 'hive being robbed', 'missing queen']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9998737

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS_1 = 10

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=EPOCHS_1
)
# Out:
# Epoch 1/10
# 21/21 [==============================] -
# 21/21 [==============================] - 6s 295ms/step - loss: 0.0994 - accuracy: 0.9667 - val_loss: 0.2972 - val_accuracy: 0.9152

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS_2)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from colorama import Fore

LENGTH = 10
bees_path = pathlib.Path("./df_test")

for x in uniqueHealths:
    n = 0
    folder = str(bees_path) + '/' + x
    print(folder)
    while(n < LENGTH):
        for filename in os.listdir(folder):
            img = tf.keras.utils.load_img(
            folder+"/"+filename, target_size=(img_height, img_width)
            )
            img_array = tf.keras.utils.img_to_array(img)
            img_array = tf.expand_dims(img_array, 0) # Create a batch

            predictions = model.predict(img_array)
            score = tf.nn.softmax(predictions[0])
            print("SCORE: " + str(score))
            print(
                ("This image most likely belongs to {} with a {:.2f} percent confidence. The correct answer was: " + x)
                .format(class_names[np.argmax(score)], 100 * np.max(score))
            )
            if x == class_names[np.argmax(score)]:
                print(Fore.GREEN + 'CORRECT!' + Fore.BLACK)
            else:
                print(Fore.RED + 'INCORRECT!' + Fore.BLACK)
            n+=1
            if n >= LENGTH:
                break;
# Out:
# df_test/hive being robbed
# 1/1 [==============================] - 0s 229ms/step
# SCORE: tf.Tensor([2.2061951e-04 2.2473987e-06 2.8602161e-02 9.6209067e-01 9.0843141e-03], shape=(5,), dtype=float32)
# This image most likely belongs to hive being robbed with a 96.21 percent confidence. The correct answer was: hive being robbed
# CORRECT!
# 1/1 [==============================] - 0s 40ms/step
# SCORE: tf.Tensor([1.7541339e-01 1.6964790e-04 8.1129044e-01 1.2492351e-02 6.3417130e-04], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 81.13 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 41ms/step
# SCORE: tf.Tensor([1.2444305e-02 5.1159873e-06 5.6906193e-03 9.8145032e-01 4.0965679e-04], shape=(5,), dtype=float32)
# This image most likely belongs to hive being robbed with a 98.15 percent confidence. The correct answer was: hive being robbed
# CORRECT!
# 1/1 [==============================] - 0s 45ms/step
# SCORE: tf.Tensor([2.8557881e-07 2.0203997e-04 6.5931571e-01 3.4048206e-01 1.0759957e-08], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 65.93 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 46ms/step
# SCORE: tf.Tensor([4.9715731e-02 3.5289695e-06 9.0196615e-01 1.5536193e-03 4.6760987e-02], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 90.20 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 44ms/step
# SCORE: tf.Tensor([2.0506440e-01 1.9812496e-05 5.7700592e-01 6.4475641e-02 1.5343420e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 57.70 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 43ms/step
# SCORE: tf.Tensor([1.5839068e-03 1.3236698e-09 6.0063171e-01 1.8844273e-02 3.7894014e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 60.06 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 45ms/step
# SCORE: tf.Tensor([6.8378136e-02 5.9941638e-09 2.3006050e-01 5.3545102e-02 6.4801627e-01], shape=(5,), dtype=float32)
# This image most likely belongs to missing queen with a 64.80 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 42ms/step
# SCORE: tf.Tensor([5.8782083e-04 9.5234633e-08 7.8982465e-02 2.2603780e-02 8.9782590e-01], shape=(5,), dtype=float32)
# This image most likely belongs to missing queen with a 89.78 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# 1/1 [==============================] - 0s 41ms/step
# SCORE: tf.Tensor([2.5720006e-01 1.7065449e-09 5.1429862e-01 4.6337888e-02 1.8216340e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 51.43 percent confidence. The correct answer was: hive being robbed
# INCORRECT!
# df_test/healthy
# 1/1 [==============================] - 0s 48ms/step
# SCORE: tf.Tensor([1.9505218e-05 3.7236785e-04 9.4438052e-01 5.5227406e-02 2.0433146e-07], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 94.44 percent confidence. The correct answer was: healthy
# CORRECT!
# 1/1 [==============================] - 0s 43ms/step
# SCORE: tf.Tensor([6.9483622e-06 7.9962076e-05 9.7193235e-01 2.7980827e-02 5.0150204e-09], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a
shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 76.12 percent confidence. The correct answer was: ant problems
# INCORRECT!
# 1/1 [==============================] - 0s 47ms/step
# SCORE: tf.Tensor([1.7450741e-04 2.9763067e-01 7.0202434e-01 1.6766842e-04 2.8088521e-06], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 70.20 percent confidence. The correct answer was: ant problems
# INCORRECT!
# 1/1 [==============================] - 0s 47ms/step
# SCORE: tf.Tensor([4.6742598e-06 9.9292189e-01 7.0047169e-03 6.8533198e-05 2.2381737e-07], shape=(5,), dtype=float32)
# This image most likely belongs to ant problems with a 99.29 percent confidence. The correct answer was: ant problems
# CORRECT!
# 1/1 [==============================] - 0s 42ms/step
# SCORE: tf.Tensor([7.3938729e-08 9.9936277e-01 6.3118374e-04 5.9371509e-06 2.1138757e-08], shape=(5,), dtype=float32)
# This image most likely belongs to ant problems with a 99.94 percent confidence. The correct answer was: ant problems
# CORRECT!
# 1/1 [==============================] - 0s 41ms/step
# SCORE: tf.Tensor([5.3083562e-07 9.9549830e-01 4.5010275e-03 2.7663316e-07 6.5312387e-09], shape=(5,), dtype=float32)
# This image most likely belongs to ant problems with a 99.55 percent confidence. The correct answer was: ant problems
# CORRECT!
# 1/1 [==============================] - 0s 39ms/step
# SCORE: tf.Tensor([1.5509455e-04 9.6871769e-01 3.1088104e-02 3.7990518e-05 1.1433424e-06], shape=(5,), dtype=float32)
# This image most likely belongs to ant problems with a 96.87 percent confidence. The correct answer was: ant problems
# CORRECT!
# 1/1 [==============================] - 0s 37ms/step
# SCORE: tf.Tensor([1.0564136e-03 9.6779990e-01 2.2097960e-02 9.0244533e-03 2.1179199e-05], shape=(5,), dtype=float32)
# This image most likely belongs to ant problems with a 96.78 percent confidence. The correct answer was: ant problems
# CORRECT!
# 1/1 [==============================] - 0s 40ms/step
# SCORE: tf.Tensor([6.4797127e-06 9.9627256e-01 3.5917272e-03 1.2545646e-04 3.8039700e-06], shape=(5,), dtype=float32)
# This image most likely belongs to ant problems with a 99.63 percent confidence. The correct answer was: ant problems
# CORRECT!
# df_test/missing queen
# 1/1 [==============================] - 0s 48ms/step
# SCORE: tf.Tensor([2.7850016e-03 3.3638091e-05 8.9767224e-01 1.6000028e-03 9.7909063e-02], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 89.77 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 42ms/step
# SCORE: tf.Tensor([1.1451865e-04 2.6514901e-05 6.7553967e-01 1.3741604e-02 3.1057772e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 67.55 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 41ms/step
# SCORE: tf.Tensor([5.4109783e-05 6.9953836e-07 5.0561130e-01 2.4120400e-02 4.7021353e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 50.56 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 45ms/step
# SCORE: tf.Tensor([0.00068108 0.00097718 0.384834   0.01415344 0.5993543 ], shape=(5,), dtype=float32)
# This image most likely belongs to missing queen with a 59.94 percent confidence. The correct answer was: missing queen
# CORRECT!
# 1/1 [==============================] - 0s 39ms/step
# SCORE: tf.Tensor([3.1489835e-04 2.9013540e-07 9.9209434e-01 5.6502788e-04 7.0254579e-03], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 99.21 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 37ms/step
# SCORE: tf.Tensor([0.0008382  0.01548139 0.25183338 0.02367398 0.70817304], shape=(5,), dtype=float32)
# This image most likely belongs to missing queen with a 70.82 percent confidence. The correct answer was: missing queen
# CORRECT!
# 1/1 [==============================] - 0s 45ms/step
# SCORE: tf.Tensor([2.7850016e-03 3.3638091e-05 8.9767224e-01 1.6000028e-03 9.7909063e-02], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 89.77 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 58ms/step
# SCORE: tf.Tensor([1.1451865e-04 2.6514901e-05 6.7553967e-01 1.3741604e-02 3.1057772e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 67.55 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 33ms/step
# SCORE: tf.Tensor([5.4109783e-05 6.9953836e-07 5.0561130e-01 2.4120400e-02 4.7021353e-01], shape=(5,), dtype=float32)
# This image most likely belongs to healthy with a 50.56 percent confidence. The correct answer was: missing queen
# INCORRECT!
# 1/1 [==============================] - 0s 42ms/step
# SCORE: tf.Tensor([0.00068108 0.00097718 0.384834   0.01415344 0.5993543 ], shape=(5,), dtype=float32)
# This image most likely belongs to missing queen with a 59.94 percent confidence. The correct answer was: missing queen
# CORRECT!

# %%
bee_path = pathlib.Path("./extra_test/blue_square.jpg")

img = tf.keras.utils.load_img(
    bee_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# This image most likely belongs to healthy with a 97.34 percent confidence.
